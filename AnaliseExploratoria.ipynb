# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# Apply the default theme
sns.set_theme()

# %%
df = pd.read_csv('metadata.csv')
df
# Out:
#      patient_id  lesion_id  smoke  drink background_father background_mother  \
# 0      PAT_1516       1765    NaN    NaN               NaN               NaN
# 1        PAT_46        881  False  False         POMERANIA         POMERANIA
# 2      PAT_1545       1867    NaN    NaN               NaN               NaN
# 3      PAT_1989       4061    NaN    NaN               NaN               NaN
# 4       PAT_684       1302  False   True         POMERANIA         POMERANIA
# ...         ...        ...    ...    ...               ...               ...
# 2293   PAT_1708       3156    NaN    NaN               NaN               NaN
# 2294     PAT_46        880  False  False         POMERANIA         POMERANIA
# 2295   PAT_1343       1217    NaN    NaN               NaN               NaN
# 2296    PAT_326        690  False  False         POMERANIA         POMERANIA
# 2297   PAT_1714       3189    NaN    NaN               NaN               NaN
#
# ...

# %%
df.columns
# Out:
# Index(['patient_id', 'lesion_id', 'smoke', 'drink', 'background_father',
#        'background_mother', 'age', 'pesticide', 'gender',
#        'skin_cancer_history', 'cancer_history', 'has_piped_water',
#        'has_sewage_system', 'fitspatrick', 'region', 'diameter_1',
#        'diameter_2', 'diagnostic', 'itch', 'grew', 'hurt', 'changed', 'bleed',
#        'elevation', 'img_id', 'biopsed'],
#       dtype='object')

# %%
df['diagnostic'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='diagnostic'>

# %% [markdown]
# # Dataframe Melanoma

# %%
df_melanoma = df[df["diagnostic"] == "MEL"]
df_melanoma
# Out:
#      patient_id  lesion_id  smoke  drink background_father background_mother  \
# 53      PAT_680       1289   True  False          PORTUGAL             ITALY
# 86      PAT_995       1867  False  False               UNK               UNK
# 112     PAT_966       1825  False  False         POMERANIA         POMERANIA
# 164     PAT_966       1825  False  False         POMERANIA         POMERANIA
# 262     PAT_495        941  False  False         POMERANIA         POMERANIA
# 266     PAT_614       1166  False  False               UNK               UNK
# 281     PAT_340        714  False   True             ITALY             ITALY
# 296     PAT_115       1138  False  False         POMERANIA         POMERANIA
# 338     PAT_895       1699  False  False           GERMANY          PORTUGAL
# 412     PAT_233        354  False  False         POMERANIA         POMERANIA
# 434     PAT_109        868   True   True             ITALY             ITALY
# ...

# %%
print(df_melanoma.shape[0])
df_melanoma.shape[0]/df.shape[0]
# Out:
# 52
# 0.022628372497824196

# %% [markdown]
# # Análise

# %% [markdown]
# ## Fatores de influência

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['background_father'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['background_father'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'background_father'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['background_mother'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['background_mother'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'background_mother'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['smoke'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['smoke'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'smoke'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['drink'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['drink'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'drink'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['pesticide'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['pesticide'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'pesticide'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['gender'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['gender'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'gender'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['skin_cancer_history'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['skin_cancer_history'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'skin_cancer_history'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['cancer_history'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['cancer_history'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'cancer_history'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['has_piped_water'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['has_piped_water'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'has_piped_water'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['has_sewage_system'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['has_sewage_system'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'has_sewage_system'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['fitspatrick'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['fitspatrick'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'fitspatrick'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
axes[0].hist(df.age, color="orange", edgecolor="#1F8F50")
axes[1].hist(df_melanoma.age, edgecolor="#1F8F50")
# Out:
# (array([ 1.,  1.,  2.,  5., 10., 11.,  8.,  8.,  4.,  2.]),
#  array([21. , 27.9, 34.8, 41.7, 48.6, 55.5, 62.4, 69.3, 76.2, 83.1, 90. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Características e evolução

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['region'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['region'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'region'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['itch'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['itch'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'itch'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['grew'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['grew'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'grew'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['hurt'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['hurt'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'hurt'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['changed'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['changed'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'changed'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['bleed'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['bleed'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'bleed'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
df['elevation'].value_counts().plot(kind='bar', ax = axes[0], subplots=True, color="orange")
df_melanoma['elevation'].value_counts().plot(kind='bar',ax = axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'elevation'}>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
axes[0].hist(df.diameter_1, bins=30, color="orange", edgecolor="#1F8F50")
axes[1].hist(df_melanoma.diameter_1, edgecolor="#1F8F50")
# Out:
# (array([ 6., 16.,  9.,  6.,  7.,  3.,  2.,  2.,  0.,  1.]),
#  array([ 5. ,  8.5, 12. , 15.5, 19. , 22.5, 26. , 29.5, 33. , 36.5, 40. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,6))
axes[0].hist(df.diameter_2, bins=30, color="orange", edgecolor="#1F8F50")
axes[1].hist(df_melanoma.diameter_2, edgecolor="#1F8F50")
# Out:
# (array([12., 13., 14.,  4.,  1.,  5.,  0.,  1.,  1.,  1.]),
#  array([ 3. ,  6.1,  9.2, 12.3, 15.4, 18.5, 21.6, 24.7, 27.8, 30.9, 34. ]),
#  <BarContainer object of 10 artists>)
