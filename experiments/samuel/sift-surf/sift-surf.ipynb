# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt
from cascid.configs.isic_cnf import IMAGES_DIR
from cascid.datasets.isic.database import get_df

# %%
dataframe = get_df()

# %%
dataframe.head()
# Out:
#         isic_id     sex diagnostic  age_approx  \
# 0  ISIC_4327928  female        MEL          55
# 1  ISIC_5608178    male        MEL          60
# 2  ISIC_0757631    male        MEL          25
# 3  ISIC_8711280  female        NEV          45
# 4  ISIC_3934294  female        NEV          45
#
#                                            image_url            img_id
# 0  https://content.isic-archive.com/d361a1ec-eb19...  ISIC_4327928.jpg
# 1  https://content.isic-archive.com/f2c041e9-24dd...  ISIC_5608178.jpg
# 2  https://content.isic-archive.com/17a0b05d-2c9d...  ISIC_0757631.jpg
# 3  https://content.isic-archive.com/d2fe8a24-8406...  ISIC_8711280.jpg
# 4  https://content.isic-archive.com/61741dc4-f201...  ISIC_3934294.jpg

# %%
def get_importance(kp_element):
    return kp_element.response

# %%
def apply_sift_surf(image_id):
    img = cv.imread(os.fspath(IMAGES_DIR) + "/" + image_id)
    im_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    resized = cv.resize(im_rgb, (256,256))
    surf = cv.SIFT_create()
    kp, des = surf.detectAndCompute(resized, None)
    list_importance = [point for point in kp]
    list_importance.sort(key=get_importance)
    list_rgb = list()
    for point in list_importance[0:6]:
        point_coordinates = point.pt
        rgb = resized[int(point_coordinates[0])][int(point_coordinates[1])]
        list_rgb.append(rgb)
    return list_rgb

# %%
dataframe["siftsurf"] = dataframe["img_id"].apply(lambda id: apply_sift_surf(id))

# %%
dataframe
# Out:
#          isic_id     sex diagnostic  age_approx  \
# 0   ISIC_4327928  female        MEL          55
# 1   ISIC_5608178    male        MEL          60
# 2   ISIC_0757631    male        MEL          25
# 3   ISIC_8711280  female        NEV          45
# 4   ISIC_3934294  female        NEV          45
# 5   ISIC_0597218  female        NEV          55
# 6   ISIC_4640181  female        BCC          70
# 7   ISIC_3148886  female        BCC          75
# 8   ISIC_2283509  female        BCC          65
# 9   ISIC_9108366    male        SEK          70
# 10  ISIC_8400705    male        SEK          75
# 11  ISIC_2003288  female        SEK          65
# 12  ISIC_6948176  female        ACK          60
# 13  ISIC_4878461  female        ACK          70
# 14  ISIC_5685440  female        ACK          80
# 15  ISIC_7697150  female        SCC          50
# 16  ISIC_7797655    male        SCC          80
# 17  ISIC_2139839  female        SCC          70
#
#                                             image_url            img_id  \
# 0   https://content.isic-archive.com/d361a1ec-eb19...  ISIC_4327928.jpg
# 1   https://content.isic-archive.com/f2c041e9-24dd...  ISIC_5608178.jpg
# 2   https://content.isic-archive.com/17a0b05d-2c9d...  ISIC_0757631.jpg
# 3   https://content.isic-archive.com/d2fe8a24-8406...  ISIC_8711280.jpg
# 4   https://content.isic-archive.com/61741dc4-f201...  ISIC_3934294.jpg
# 5   https://content.isic-archive.com/f8b46c8f-08e9...  ISIC_0597218.jpg
# 6   https://content.isic-archive.com/bf63d484-8591...  ISIC_4640181.jpg
# 7   https://content.isic-archive.com/02176c48-2e9d...  ISIC_3148886.jpg
# 8   https://content.isic-archive.com/a1e7f4d3-6408...  ISIC_2283509.jpg
# 9   https://content.isic-archive.com/539913ef-50dd...  ISIC_9108366.jpg
# 10  https://content.isic-archive.com/e1be135a-6d8f...  ISIC_8400705.jpg
# 11  https://content.isic-archive.com/dd9428df-b87a...  ISIC_2003288.jpg
# 12  https://content.isic-archive.com/0d549a98-fe05...  ISIC_6948176.jpg
# 13  https://content.isic-archive.com/630445c6-c880...  ISIC_4878461.jpg
# 14  https://content.isic-archive.com/040dea1e-f813...  ISIC_5685440.jpg
# 15  https://content.isic-archive.com/79c7b482-6031...  ISIC_7697150.jpg
# 16  https://content.isic-archive.com/ea0bb58b-9449...  ISIC_7797655.jpg
# 17  https://content.isic-archive.com/8ac78013-0a33...  ISIC_2139839.jpg
#
#                                              siftsurf
# 0   [[172, 81, 37], [219, 157, 80], [220, 164, 135...
# 1   [[138, 76, 55], [155, 100, 87], [160, 122, 113...
# 2   [[216, 177, 134], [228, 191, 148], [220, 150, ...
# 3   [[149, 74, 42], [193, 131, 94], [222, 182, 171...
# 4   [[221, 177, 142], [143, 85, 42], [230, 191, 15...
# 5   [[164, 136, 133], [178, 150, 146], [186, 159, ...
# 6   [[204, 165, 124], [195, 162, 181], [190, 142, ...
# 7   [[201, 178, 180], [201, 178, 180], [221, 183, ...
# 8   [[201, 136, 96], [226, 191, 153], [207, 172, 1...
# 9   [[154, 130, 119], [154, 130, 119], [138, 105, ...
# 10  [[102, 67, 48], [230, 215, 182], [106, 73, 58]...
# 11  [[204, 157, 141], [192, 127, 87], [217, 158, 9...
# 12  [[177, 132, 174], [183, 122, 156], [174, 131, ...
# 13  [[210, 154, 189], [210, 154, 189], [185, 155, ...
# 14  [[124, 92, 107], [206, 160, 162], [54, 38, 25]...
# 15  [[232, 213, 215], [196, 163, 112], [196, 163, ...
# 16  [[225, 175, 153], [226, 186, 188], [110, 70, 1...
# 17  [[199, 175, 147], [181, 151, 141], [141, 117, ...
